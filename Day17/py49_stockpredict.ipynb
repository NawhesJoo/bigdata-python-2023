# %% [markdown]
# #### 시계열 분석을 위한 기본학습
#
# ##### 기본용어
#
# - 추세(Trend) : 시간에 따라 감소/증가하는 성향
# - 계절성(Seasonality) : 계절에 따라 패턴을 가지는 성향
# - 순환성(Cyclical) : 특정상황에서 발생하는 임시적인 성향(추세)
# - 불규칙성(Irregular) : 지진,홍수,파업,코로나 같은 특수한 요인으로 발생하는 불규칙 패턴

# %% [markdown]
# ##### 시계열 데이터 전처리방법

# %%
import pandas as pd
import numpy as np

# %%
# datetime 변환
df = pd.DataFrame({'date': ['2019-01-03', '2021-11-24', '2023-07-11'], 'name':['JH', 'YS', 'OB']})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      object
#  1   name    3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
# date 컬럼 datetime 형변환
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      datetime64[ns]
#  1   name    3 non-null      object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 180.0+ bytes

# %%
df.astype({'date':'datetime64[ns]'})
# Out:
#         date name
# 0 2019-01-03   JH
# 1 2021-11-24   YS
# 2 2023-07-11   OB

# %%
# 날짜를 인덱스로 변경
df.set_index(keys=['date'], inplace=True)
df
# Out:
#            name
# date
# 2019-01-03   JH
# 2021-11-24   YS
# 2023-07-11   OB

# %%
# 날짜를 인덱스에서 해제(인덱스 초기화)
df.reset_index(inplace=True)
df
# Out:
#         date name
# 0 2019-01-03   JH
# 1 2021-11-24   YS
# 2 2023-07-11   OB

# %%
# 결측치 확인 
# 결측치값 python None, numpy nan
df = pd.DataFrame({'date': ['2019-01-03', '2021-11-24', '2022-01-15', '2023-07-11'], 'x1':[0.1, 2.0, np.nan, 1.2]})
df
# Out:
#          date   x1
# 0  2019-01-03  0.1
# 1  2021-11-24  2.0
# 2  2022-01-15  NaN
# 3  2023-07-11  1.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4 non-null      object
#  1   x1      3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df = df.astype({'date':'datetime64[ns]'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4 non-null      datetime64[ns]
#  1   x1      3 non-null      float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 196.0 bytes

# %%
# 날짜를 인덱스
df.set_index(keys=['date'], inplace=True)
df
# Out:
#              x1
# date
# 2019-01-03  0.1
# 2021-11-24  2.0
# 2022-01-15  NaN
# 2023-07-11  1.2

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# x1    1
# dtype: int64

# %%
# 결측치 제거, inplace=True 변경 결정 ffill 이전값으로 대체
df.fillna(method='ffill')
# Out:
#              x1
# date
# 2019-01-03  0.1
# 2021-11-24  2.0
# 2022-01-15  2.0
# 2023-07-11  1.2

# %%
# bfill 밑의 값으로 대체
df.fillna(method='bfill')
# Out:
#              x1
# date
# 2019-01-03  0.1
# 2021-11-24  2.0
# 2022-01-15  1.2
# 2023-07-11  1.2

# %%
# 결측치 전후의 값의 평균으로 채우기
df.interpolate()
# Out:
#              x1
# date
# 2019-01-03  0.1
# 2021-11-24  2.0
# 2022-01-15  1.6
# 2023-07-11  1.2

# %%
# 결측지 제거 -> 데이터수 변경
df.dropna()
# Out:
#              x1
# date
# 2019-01-03  0.1
# 2021-11-24  2.0
# 2023-07-11  1.2

# %%
# 빈도 설정
df.index
# Out:
# DatetimeIndex(['2019-01-03', '2021-11-24', '2022-01-15', '2023-07-11'], dtype='datetime64[ns]', name='date', freq=None)

# %%
# 'Y 매년 마지막날, 'M', 'D', 'W', 'SM', 'CBM', 'MS', 'Q', 'QS', 'H', 'T', 'S', 'N'
df.asfreq(freq='D', method='bfill')
# Out:
#              x1
# date
# 2019-01-03  0.1
# 2019-01-04  2.0
# 2019-01-05  2.0
# 2019-01-06  2.0
# 2019-01-07  2.0
# ...         ...
# 2023-07-07  1.2
# 2023-07-08  1.2
# 2023-07-09  1.2
# 2023-07-10  1.2
# 2023-07-11  1.2
#
# [1651 rows x 1 columns]

# %%
# rolling - 빈도범위를 다시 묶을때 특정값이 사라지는 경우 방지
df = pd.DataFrame({'date': ['2019-01-03', '2020-09-04', '2021-11-24', '2022-01-15', '2023-07-11'], 'x1':[5,4,3,2,7]})
df = df.astype({'date':'datetime64[ns]'})
df.set_index(keys=['date'], inplace=True)
df
# Out:
#             x1
# date
# 2019-01-03   5
# 2020-09-04   4
# 2021-11-24   3
# 2022-01-15   2
# 2023-07-11   7

# %%
# rolling(1) 현재자기값을 그대로 평균
df.rolling(1).mean()
# Out:
#              x1
# date
# 2019-01-03  5.0
# 2020-09-04  4.0
# 2021-11-24  3.0
# 2022-01-15  2.0
# 2023-07-11  7.0

# %%
# rolling(2) 현재값을 밑으로 밀면서 자기값과 합쳐서 평균
df.rolling(2).mean()
# Out:
#              x1
# date
# 2019-01-03  NaN
# 2020-09-04  4.5
# 2021-11-24  3.5
# 2022-01-15  2.5
# 2023-07-11  4.5

# %%
# 이전값과 차이 계산 diff
y_diff = df.diff()
y_diff.columns = ['diff']

# %%
pd.concat([df, y_diff], axis=1)
# Out:
#             x1  diff
# date
# 2019-01-03   5   NaN
# 2020-09-04   4  -1.0
# 2021-11-24   3  -1.0
# 2022-01-15   2  -1.0
# 2023-07-11   7   5.0

# %%
# 데이터 밀기
df.shift(-1)
# Out:
#              x1
# date
# 2019-01-03  4.0
# 2020-09-04  3.0
# 2021-11-24  2.0
# 2022-01-15  7.0
# 2023-07-11  NaN

# %%
# 원-핫 인코딩 one-hot encoding
df_raw = pd.DataFrame({'color':['red','blue','green','blue','red']})

one_hot = pd.get_dummies(df_raw['color'])

# %%
one_hot
# Out:
#     blue  green    red
# 0  False  False   True
# 1   True  False  False
# 2  False   True  False
# 3   True  False  False
# 4  False  False   True

# %%
# True/False 대신 1/0 표시
df_raw.pop('color').str.get_dummies()
# Out:
#    blue  green  red
# 0     0      0    1
# 1     1      0    0
# 2     0      1    0
# 3     1      0    0
# 4     0      0    1

# %% [markdown]
# ##### Apple 주식 데이터 전처리
#
# ##### 주식관련 라이브러리 설치
# - FinanceDataReader 모듈 설치
#
# ```python
# !pip install finance-DataReader
# ```

# %%
# !pip install finance-DataReader
# Out:
# Requirement already satisfied: finance-DataReader in c:\program files\python311\lib\site-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in c:\program files\python311\lib\site-packages (from finance-DataReader) (2.0.2)
# Requirement already satisfied: requests>=2.3.0 in c:\program files\python311\lib\site-packages (from finance-DataReader) (2.31.0)
# Requirement already satisfied: requests-file in c:\program files\python311\lib\site-packages (from finance-DataReader) (1.5.1)
# Requirement already satisfied: lxml in c:\program files\python311\lib\site-packages (from finance-DataReader) (4.9.3)
# Requirement already satisfied: tqdm in c:\program files\python311\lib\site-packages (from finance-DataReader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python311\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python311\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\program files\python311\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\program files\python311\lib\site-packages (from pandas>=0.19.2->finance-DataReader) (1.25.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python311\lib\site-packages (from requests>=2.3.0->finance-DataReader) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python311\lib\site-packages (from requests>=2.3.0->finance-DataReader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python311\lib\site-packages (from requests>=2.3.0->finance-DataReader) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python311\lib\site-packages (from requests>=2.3.0->finance-DataReader) (2023.5.7)
# Requirement already satisfied: six in c:\program files\python311\lib\site-packages (from requests-file->finance-DataReader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\roaming\python\python311\site-packages (from tqdm->finance-DataReader) (0.4.6)

# %%
import FinanceDataReader as fdr  # 주식라이브러리 추가

import matplotlib
# from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc, rcParams
import seaborn as sns

import pandas as pd
import numpy as np

font_path = 'C:/Windows/Fonts/NanumGothic.ttf'
font = font_manager.FontProperties(fname=font_path).get_name() # 'NanumGothic'
rc('font', family=font)
rcParams['axes.unicode_minus'] = False

# %%
# 2022년 애플주식 데이터로드
# 미국주식은 주식코드, 우리나라 코드번호
df = fdr.DataReader('AAPL', '2016')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   25.652500   26.342501   25.500000   26.337500   24.041485
# 2016-01-05   26.437500   26.462500   25.602501   25.677500   23.439028
# 2016-01-06   25.139999   25.592501   24.967501   25.174999   22.980330
# 2016-01-07   24.670000   25.032499   24.107500   24.112499   22.010450
# 2016-01-08   24.637501   24.777500   24.190001   24.240000   22.126839
# ...                ...         ...         ...         ...         ...
# 2023-07-05  191.570007  192.979996  190.619995  191.330002  191.330002
# 2023-07-06  189.839996  192.020004  189.199997  191.809998  191.809998
# 2023-07-07  191.410004  192.669998  190.240005  190.679993  190.679993
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.279999  186.600006  188.080002  188.080002
#
#                Volume
# Date
# 2016-01-04  270597600
# 2016-01-05  223164000
# 2016-01-06  273829600
# 2016-01-07  324377600
# 2016-01-08  283192000
# ...               ...
# 2023-07-05   46920300
# 2023-07-06   45094300
# 2023-07-07   46778000
# 2023-07-10   59922200
# 2023-07-11   46509718
#
# [1892 rows x 6 columns]

# %%
# KRX : 한국주식거래 전체 종목, KOSPI : 코스피 종목, KOSDAQ : 코스닥 종목, KONEX : 중소기업용 
# NASDAQ : 나스닥, NYSE : 뉴욕증권거래소, AMEX : 미국주식 섹터정보, SP500 : S&P 종목
# HKEX : 홍콩주식
df_krx = fdr.StockListing('KRX')
df_krx
# Out:
#         Code        ISU_CD      Name  Market         Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자   KOSPI                71500          3
# 1     373220  KR7373220003  LG에너지솔루션   KOSPI               534000          2
# 2     000660  KR7000660001    SK하이닉스   KOSPI               114100          1
# 3     207940  KR7207940008  삼성바이오로직스   KOSPI               720000          2
# 4     005935  KR7005931001     삼성전자우   KOSPI                59300          3
# ...      ...           ...       ...     ...          ...     ...        ...
# 2729  078650  KR7078650009     지나인제약  KOSDAQ  관리종목(소속부없음)     550          2
# 2730  322190  KR7322190000        베른   KONEX        일반기업부     154          1
# 2731  004565  KR7004561007  현대비앤지스틸우   KOSPI                11200          1
# 2732  308700  KR7308700004       테크엔   KONEX        일반기업부     255          0
# 2733  000547  KR7000542001   흥국화재2우B   KOSPI                 6500          2
#
#       Changes  ChagesRatio    Open    High     Low   Volume        Amount  \
# 0           0         0.00   71200   72000   71100  2295691  164277959100
# 1      -16000        -2.91  538000  538000  530000  1097569  579539612500
# 2         700         0.62  113200  114800  112800   402560   45858153623
# 3       -3000        -0.41  722000  723000  715000     6942    4993338000
# 4           0         0.00   59300   59600   59100    92330    5476993600
# ...       ...          ...     ...     ...     ...      ...           ...
# 2729    -1570       -74.06     550     550     550    87503      48126650
# 2730       19        14.07     154     154     154        1           154
# 2731       80         0.72   11200   11200   11200     5253      58724880
# 2732        0         0.00       0       0       0        0             0
# 2733     -120        -1.81    6500    6500    6500     3359      21845980
#
#                Marcap      Stocks MarketId
# 0     426839452325000  5969782550      STK
# 1     124956000000000   234000000      STK
# 2      83065069846500   728002365      STK
# 3      51245280000000    71174000      STK
# 4      48797181310000   822886700      STK
# ...               ...         ...      ...
# 2729       2243327350     4078777      KSQ
# 2730       1374480338     8925197      KNX
# 2731       1230342400      109852      STK
# 2732       1020000000     4000000      KNX
# 2733        998400000      153600      STK
#
# [2734 rows x 17 columns]

# %%
df_nasdaq = fdr.StockListing('NASDAQ')
df_nasdaq
# Out:
# 100%|██████████| 4238/4238 [00:09<00:00, 463.98it/s]
#      Symbol                                           Name     Industry  \
# 0      AAPL                                      Apple Inc   전화 및 소형 장치
# 1      MSFT                                 Microsoft Corp        소프트웨어
# 2      AMZN                                 Amazon.com Inc          백화점
# 3      NVDA                                    NVIDIA Corp          반도체
# 4      TSLA                                      Tesla Inc  자동차 및 트럭 제조
# ...     ...                                            ...          ...
# 4233  TBMCR    Trailblazer Merger Rights Exp 21 April 2028     투자 지주 회사
# 4234  OAKUR  Oak Woods Acquisition Rights Exp 3 March 2028     투자 지주 회사
# 4235   SXTP                 60 Degrees Pharmaceuticals Inc           제약
# 4236  GODNR  Golden Star Acquisition Rights Exp 1 May 2028     투자 지주 회사
# 4237  PSNYW         Polestar Automotive Holding Uk Plc ADR  자동차 및 트럭 제조
#
#      IndustryCode
# 0        57106020
# 1        57201020
# 2        53402010
# 3        57101010
# 4        53101010
# ...           ...
# 4233     55601010
# 4234     55601010
# 4235     56201040
# 4236     55601010
# 4237     53101010
#
# [4238 rows x 4 columns]

# %%
# 애플 주식 시각화
plt.figure(figsize=(15, 6))
plt.title('애플 주식 2022년 부터 주가 그래프')
plt.xlabel('날짜')
plt.ylabel('가격($)')

sns.lineplot(x=df.index, y=df['Close'], label='종가')
sns.lineplot(x=df.index, y=df['Open'], label='시작가')
sns.lineplot(x=df.index, y=df['High'], label='상한가')
plt.legend()
plt.show()

# %%
# 삼성전자
df_samsung = fdr.DataReader('005930', '2019')
df_samsung
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2019-01-02  39400  39400  38550  38750   7847664  0.001292
# 2019-01-03  38300  38550  37450  37600  12471493 -0.029677
# 2019-01-04  37450  37600  36850  37450  14108958 -0.003989
# 2019-01-07  38000  38900  37800  38750  12748997  0.034713
# 2019-01-08  38000  39200  37950  38100  12756554 -0.016774
# ...           ...    ...    ...    ...       ...       ...
# 2023-07-06  71900  72400  71500  71600  14777667 -0.005556
# 2023-07-07  71100  71400  69800  69900  17308877 -0.023743
# 2023-07-10  70000  70400  69200  69500  11713926 -0.005722
# 2023-07-11  70200  71500  70100  71500  12177392  0.028777
# 2023-07-12  71200  72000  71100  71400   2992626 -0.001399
#
# [1119 rows x 6 columns]

# %%
# 삼성전자 주식 시각화
plt.figure(figsize=(15, 6))
plt.title('삼성전자 주식 2019년 이후 주가')
plt.xlabel('날짜')
plt.ylabel('가격(원)')

sns.lineplot(x=df_samsung.index, y=df_samsung['Close'])
plt.show()

# %% [markdown]
# ##### 시계열 데이터 전처리 추가

# %%
# 다운샘플링, BM = 주말, 공휴일을 제외한 매달 말일, Y, M, W, Q
# 업샘플링, 기준 날짜(D) --> H(시), T(분), S(초)
# 2023-07-31 오류
df_apple_mon = df.resample('BM').mean()
df_apple_mon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91 entries, 2016-01-29 to 2023-07-31
# Freq: BM
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       91 non-null     float64
#  1   High       91 non-null     float64
#  2   Low        91 non-null     float64
#  3   Close      91 non-null     float64
#  4   Adj Close  91 non-null     float64
#  5   Volume     91 non-null     float64
# dtypes: float64(6)
# memory usage: 5.0 KB

# %%
# 수익률 추가 = (매도가격-매수가격)/매도가격 
df_apple_mon['rtn'] = df_apple_mon['Close'].pct_change()
df_apple_mon
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-29   24.676579   24.987368   24.232105   24.607237   22.462061
# 2016-02-29   23.924000   24.181875   23.677875   23.936625   21.950689
# 2016-03-31   25.954205   26.224318   25.807841   26.066818   23.923515
# 2016-04-29   26.696429   26.939762   26.463810   26.684762   24.490650
# 2016-05-31   23.739643   23.923690   23.512262   23.743690   21.905254
# ...                ...         ...         ...         ...         ...
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.750734
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.817817
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.526194
# 2023-06-30  183.679048  185.438095  182.615714  184.283333  184.283333
# 2023-07-31  190.836668  191.803335  189.243332  190.495000  190.495000
#
#                   Volume       rtn
# Date
# 2016-01-29  2.677575e+08       NaN
# 2016-02-29  1.621725e+08 -0.027253
# 2016-03-31  1.356454e+08  0.088993
# 2016-04-29  1.661683e+08  0.023706
# 2016-05-31  1.715565e+08 -0.110215
# ...                  ...       ...
# 2023-03-31  6.609855e+07  0.026472
# 2023-04-28  5.103735e+07  0.065054
# 2023-05-31  5.796161e+07  0.045908
# 2023-06-30  6.176672e+07  0.067550
# 2023-07-31  4.611379e+07  0.033707
#
# [91 rows x 7 columns]

# %%
# 수익률 시각화
plt.figure(figsize=(16, 6))
plt.title('애플 주가 시각화 2016~2023')
plt.xlabel('날짜(매달 말일)')
plt.ylabel('수익률')

sns.lineplot(x=df_apple_mon.index, y=df_apple_mon['rtn'])
plt.show()

# %%
# 종가/수익률 시각화(다중 차트)
# plt.figure(figsize=(20, 6))
fig, axe1 = plt.subplots()
fig.set_figheight(6) # subplot일때는 figsize 조정함수 사용할 것
fig.set_figwidth(16)

axe2 = axe1.twinx()
plt.title('애플 주가 시각화 2016~2023')
plt.xlabel('날짜(매달 말일)')
# 서브플롯의 label 입력
c1 = sns.lineplot(ax=axe1, data=df_apple_mon, x=df_apple_mon.index, y='Close', color='blue', label='종가')
c2 = sns.lineplot(ax=axe2, data=df_apple_mon, x=df_apple_mon.index, y='rtn', color='red', label='수익률')

axe1.set_ylabel('종가($)')
axe2.set_ylabel('수익률')
plt.legend() # 범례를 표시
plt.show()

# %%
df_apple_mon
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-29   24.676579   24.987368   24.232105   24.607237   22.462061
# 2016-02-29   23.924000   24.181875   23.677875   23.936625   21.950689
# 2016-03-31   25.954205   26.224318   25.807841   26.066818   23.923515
# 2016-04-29   26.696429   26.939762   26.463810   26.684762   24.490650
# 2016-05-31   23.739643   23.923690   23.512262   23.743690   21.905254
# ...                ...         ...         ...         ...         ...
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.750734
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.817817
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.526194
# 2023-06-30  183.679048  185.438095  182.615714  184.283333  184.283333
# 2023-07-31  190.836668  191.803335  189.243332  190.495000  190.495000
#
#                   Volume       rtn
# Date
# 2016-01-29  2.677575e+08       NaN
# 2016-02-29  1.621725e+08 -0.027253
# 2016-03-31  1.356454e+08  0.088993
# 2016-04-29  1.661683e+08  0.023706
# 2016-05-31  1.715565e+08 -0.110215
# ...                  ...       ...
# 2023-03-31  6.609855e+07  0.026472
# 2023-04-28  5.103735e+07  0.065054
# 2023-05-31  5.796161e+07  0.045908
# 2023-06-30  6.176672e+07  0.067550
# 2023-07-31  4.611379e+07  0.033707
#
# [91 rows x 7 columns]

# %%
# 5일 이동평균선 - 최근 5일간의 종가기준 합산 뒤 5로 나는 평균
# 60일 이동평균선 - 이전 2달동안 종가 기준 평균
df_apple_mon['ma60'] = df_apple_mon['Close'].rolling(2).mean()
df_apple_mon
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-29   24.676579   24.987368   24.232105   24.607237   22.462061
# 2016-02-29   23.924000   24.181875   23.677875   23.936625   21.950689
# 2016-03-31   25.954205   26.224318   25.807841   26.066818   23.923515
# 2016-04-29   26.696429   26.939762   26.463810   26.684762   24.490650
# 2016-05-31   23.739643   23.923690   23.512262   23.743690   21.905254
# ...                ...         ...         ...         ...         ...
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.750734
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.817817
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.526194
# 2023-06-30  183.679048  185.438095  182.615714  184.283333  184.283333
# 2023-07-31  190.836668  191.803335  189.243332  190.495000  190.495000
#
#                   Volume       rtn        ma60
# Date
# 2016-01-29  2.677575e+08       NaN         NaN
# 2016-02-29  1.621725e+08 -0.027253   24.271931
# 2016-03-31  1.356454e+08  0.088993   25.001722
# 2016-04-29  1.661683e+08  0.023706   26.375790
# 2016-05-31  1.715565e+08 -0.110215   25.214226
# ...                  ...       ...         ...
# 2023-03-31  6.609855e+07  0.026472  152.966601
# 2023-04-28  5.103735e+07  0.065054  160.005286
# 2023-05-31  5.796161e+07  0.045908  168.834259
# 2023-06-30  6.176672e+07  0.067550  178.453030
# 2023-07-31  4.611379e+07  0.033707  187.389167
#
# [91 rows x 8 columns]

# %%
# 5일 이동평균 값
df['ma5'] = df['Close'].rolling(5).mean()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   25.652500   26.342501   25.500000   26.337500   24.041485
# 2016-01-05   26.437500   26.462500   25.602501   25.677500   23.439028
# 2016-01-06   25.139999   25.592501   24.967501   25.174999   22.980330
# 2016-01-07   24.670000   25.032499   24.107500   24.112499   22.010450
# 2016-01-08   24.637501   24.777500   24.190001   24.240000   22.126839
# ...                ...         ...         ...         ...         ...
# 2023-07-05  191.570007  192.979996  190.619995  191.330002  191.330002
# 2023-07-06  189.839996  192.020004  189.199997  191.809998  191.809998
# 2023-07-07  191.410004  192.669998  190.240005  190.679993  190.679993
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.279999  186.600006  188.080002  188.080002
#
#                Volume         ma5
# Date
# 2016-01-04  270597600         NaN
# 2016-01-05  223164000         NaN
# 2016-01-06  273829600         NaN
# 2016-01-07  324377600         NaN
# 2016-01-08  283192000   25.108500
# ...               ...         ...
# 2023-07-05   46920300  191.320001
# 2023-07-06   45094300  191.832001
# 2023-07-07   46778000  192.050000
# 2023-07-10   59922200  190.978000
# 2023-07-11   46509718  190.101999
#
# [1892 rows x 7 columns]

# %%
# 20일 이동평균값, 60일 경우는 rolling(60)
df['ma20'] = df['Close'].rolling(20).mean()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   25.652500   26.342501   25.500000   26.337500   24.041485
# 2016-01-05   26.437500   26.462500   25.602501   25.677500   23.439028
# 2016-01-06   25.139999   25.592501   24.967501   25.174999   22.980330
# 2016-01-07   24.670000   25.032499   24.107500   24.112499   22.010450
# 2016-01-08   24.637501   24.777500   24.190001   24.240000   22.126839
# ...                ...         ...         ...         ...         ...
# 2023-07-05  191.570007  192.979996  190.619995  191.330002  191.330002
# 2023-07-06  189.839996  192.020004  189.199997  191.809998  191.809998
# 2023-07-07  191.410004  192.669998  190.240005  190.679993  190.679993
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.279999  186.600006  188.080002  188.080002
#
#                Volume         ma5        ma20
# Date
# 2016-01-04  270597600         NaN         NaN
# 2016-01-05  223164000         NaN         NaN
# 2016-01-06  273829600         NaN         NaN
# 2016-01-07  324377600         NaN         NaN
# 2016-01-08  283192000   25.108500         NaN
# ...               ...         ...         ...
# 2023-07-05   46920300  191.320001  185.656001
# 2023-07-06   45094300  191.832001  186.286000
# 2023-07-07   46778000  192.050000  186.928999
# 2023-07-10   59922200  190.978000  187.330999
# 2023-07-11   46509718  190.101999  187.686999
#
# [1892 rows x 8 columns]

# %% [markdown]
# ##### 이동평균선 차트
#
# - 데이터 일차트, 월차트, 5일, 20일, 60일 이동평균값

# %%
# 데이터프레임 하나만 가지고 라인차트 그리기
df_apple_mon.iloc[:,[3,7]].plot(figsize=(16, 6))
plt.title('애플 월 종가 및 60일 이평선')
plt.xlabel('날짜')
plt.ylabel('금액($)')
plt.legend(['종가', '60일 이평선'])
plt.show()

# %%
df.iloc[:,[3,6,7]].plot(figsize=(16,6))
plt.title('애플 일 종가 및 5, 20일 이평선')
plt.xlabel('날짜')
plt.ylabel('금액($)')
plt.legend(['종가', '5일 이평선', '20일 이평선'])
plt.show()

# %%
# 두차트 합치기
df_apple_ma = df.resample('BM').mean()
df_apple_ma
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-29   24.676579   24.987368   24.232105   24.607237   22.462061
# 2016-02-29   23.924000   24.181875   23.677875   23.936625   21.950689
# 2016-03-31   25.954205   26.224318   25.807841   26.066818   23.923515
# 2016-04-29   26.696429   26.939762   26.463810   26.684762   24.490650
# 2016-05-31   23.739643   23.923690   23.512262   23.743690   21.905254
# ...                ...         ...         ...         ...         ...
# 2023-03-31  154.455218  156.363044  153.241304  154.964782  154.750734
# 2023-04-28  164.437370  165.925790  163.552632  165.045790  164.817817
# 2023-05-31  172.510456  173.752728  171.444545  172.622728  172.526194
# 2023-06-30  183.679048  185.438095  182.615714  184.283333  184.283333
# 2023-07-31  190.836668  191.803335  189.243332  190.495000  190.495000
#
#                   Volume         ma5        ma20
# Date
# 2016-01-29  2.677575e+08   24.549700         NaN
# 2016-02-29  1.621725e+08   23.915000   24.121725
# 2016-03-31  1.356454e+08   25.798455   24.983290
# 2016-04-29  1.661683e+08   26.984167   26.917381
# 2016-05-31  1.715565e+08   23.644905   24.600667
# ...                  ...         ...         ...
# 2023-03-31  6.609855e+07  153.663478  151.662478
# 2023-04-28  5.103735e+07  164.526106  161.448447
# 2023-05-31  5.796161e+07  171.809000  168.972546
# 2023-06-30  6.176672e+07  182.888476  178.573572
# 2023-07-31  4.611379e+07  191.158000  186.492916
#
# [91 rows x 8 columns]

# %%
df_apple_ma[['Close','ma5','ma20']]
# Out:
#                  Close         ma5        ma20
# Date
# 2016-01-29   24.607237   24.549700         NaN
# 2016-02-29   23.936625   23.915000   24.121725
# 2016-03-31   26.066818   25.798455   24.983290
# 2016-04-29   26.684762   26.984167   26.917381
# 2016-05-31   23.743690   23.644905   24.600667
# ...                ...         ...         ...
# 2023-03-31  154.964782  153.663478  151.662478
# 2023-04-28  165.045790  164.526106  161.448447
# 2023-05-31  172.622728  171.809000  168.972546
# 2023-06-30  184.283333  182.888476  178.573572
# 2023-07-31  190.495000  191.158000  186.492916
#
# [91 rows x 3 columns]

# %%
df_apple_mon[['Close','ma60']]
# Out:
#                  Close        ma60
# Date
# 2016-01-29   24.607237         NaN
# 2016-02-29   23.936625   24.271931
# 2016-03-31   26.066818   25.001722
# 2016-04-29   26.684762   26.375790
# 2016-05-31   23.743690   25.214226
# ...                ...         ...
# 2023-03-31  154.964782  152.966601
# 2023-04-28  165.045790  160.005286
# 2023-05-31  172.622728  168.834259
# 2023-06-30  184.283333  178.453030
# 2023-07-31  190.495000  187.389167
#
# [91 rows x 2 columns]

# %%
# 5, 20일 이평션 DF, 60일 이평선 DF 합치기
df_apple_total = pd.concat([df_apple_ma[['Close','ma5','ma20']], df_apple_mon[['ma60']]], axis=1)
df_apple_total
# Out:
#                  Close         ma5        ma20        ma60
# Date
# 2016-01-29   24.607237   24.549700         NaN         NaN
# 2016-02-29   23.936625   23.915000   24.121725   24.271931
# 2016-03-31   26.066818   25.798455   24.983290   25.001722
# 2016-04-29   26.684762   26.984167   26.917381   26.375790
# 2016-05-31   23.743690   23.644905   24.600667   25.214226
# ...                ...         ...         ...         ...
# 2023-03-31  154.964782  153.663478  151.662478  152.966601
# 2023-04-28  165.045790  164.526106  161.448447  160.005286
# 2023-05-31  172.622728  171.809000  168.972546  168.834259
# 2023-06-30  184.283333  182.888476  178.573572  178.453030
# 2023-07-31  190.495000  191.158000  186.492916  187.389167
#
# [91 rows x 4 columns]

# %%
df_apple_total.to_csv('./apple_total.csv', encoding='utf-8')

# %%
df_apple_total.loc['2019-06-28':]
# Out:
#                  Close         ma5        ma20        ma60
# Date
# 2019-06-28   48.242250   47.697500   46.638719   48.030330
# 2019-07-31   51.304091   51.032432   50.174961   49.773171
last_close = df_apple_total['ma60'].iloc[-2]
price = df_apple_total['Close'].iloc[-1]
print(f'60일전 종가 : ${last_close:.2f}, 전일 종가 : ${price:.2f}')

if price >= last_close:
    print('상승장')
else:
    print('하락장')
# Out:
# 60일전 종가 : $178.45, 전일 종가 : $190.50
# 상승장

# %%
# 파일 저장
df_excel = df_apple_total.reset_index()
df_excel = df_excel.astype({'Date':'string'}) # 날짜는 문자열로 형변환 후
df_excel.to_excel('./apple_total.xlsx', index=False)

# %% [markdown]
# ##### statsmodels 모듈
# - 머신러닝 탑재된 시세예측 라이브러리
#
# ```python
# !pip install statsmodels
# ```

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp311-cp311-win_amd64.whl (9.2 MB)
#                                               0.0/9.2 MB ? eta -:--:--
#      --                                       0.5/9.2 MB 9.6 MB/s eta 0:00:01
#      ----                                     1.0/9.2 MB 10.7 MB/s eta 0:00:01
#      ------                                   1.6/9.2 MB 12.5 MB/s eta 0:00:01
#      ---------                                2.1/9.2 MB 11.3 MB/s eta 0:00:01
#      -----------                              2.7/9.2 MB 11.4 MB/s eta 0:00:01
#      --------------                           3.2/9.2 MB 12.1 MB/s eta 0:00:01
#      ----------------                         3.8/9.2 MB 11.5 MB/s eta 0:00:01
#      ------------------                       4.3/9.2 MB 11.6 MB/s eta 0:00:01
#      ---------------------                    4.9/9.2 MB 11.6 MB/s eta 0:00:01
#      -----------------------                  5.4/9.2 MB 11.9 MB/s eta 0:00:01
#      -------------------------                6.0/9.2 MB 11.9 MB/s eta 0:00:01
#      ----------------------------             6.5/9.2 MB 11.6 MB/s eta 0:00:01
#      ------------------------------           7.1/9.2 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------        7.7/9.2 MB 11.7 MB/s eta 0:00:01
#      -----------------------------------      8.2/9.2 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------   8.7/9.2 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  9.2/9.2 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------- 9.2/9.2 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18 in c:\program files\python311\lib\site-packages (from statsmodels) (1.25.0)
# Collecting scipy!=1.9.2,>=1.4 (from statsmodels)
#   Downloading scipy-1.11.1-cp311-cp311-win_amd64.whl (44.0 MB)
#                                               0.0/44.0 MB ? eta -:--:--
#                                               0.5/44.0 MB 15.9 MB/s eta 0:00:03
#                                               1.1/44.0 MB 13.4 MB/s eta 0:00:04
#      -                                        1.6/44.0 MB 12.8 MB/s eta 0:00:04
#      -                                        2.2/44.0 MB 12.5 MB/s eta 0:00:04
#      --                                       2.7/44.0 MB 12.3 MB/s eta 0:00:04
#      --                                       3.3/44.0 MB 12.2 MB/s eta 0:00:04
#      ---                                      3.8/44.0 MB 12.1 MB/s eta 0:00:04
#      ---                                      4.4/44.0 MB 12.1 MB/s eta 0:00:04
#      ----                                     4.9/44.0 MB 12.1 MB/s eta 0:00:04
#      ----                                     5.4/44.0 MB 12.0 MB/s eta 0:00:04
(2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\program files\python311\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\program files\python311\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-0.5.3 scipy-1.11.1 statsmodels-0.14.0

# %%
# from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm

# %%
df = pd.read_csv('./apple_total.csv', encoding='utf-8')
df
# Out:
#           Date       Close         ma5        ma20        ma60
# 0   2016-01-29   24.607237   24.549700         NaN         NaN
# 1   2016-02-29   23.936625   23.915000   24.121725   24.271931
# 2   2016-03-31   26.066818   25.798455   24.983290   25.001722
# 3   2016-04-29   26.684762   26.984167   26.917381   26.375790
# 4   2016-05-31   23.743690   23.644905   24.600667   25.214226
# ..         ...         ...         ...         ...         ...
# 86  2023-03-31  154.964782  153.663478  151.662478  152.966601
# 87  2023-04-28  165.045790  164.526106  161.448447  160.005286
# 88  2023-05-31  172.622728  171.809000  168.972546  168.834259
# 89  2023-06-30  184.283333  182.888476  178.573572  178.453030
# 90  2023-07-31  190.495001  191.158000  186.492916  187.389167
#
# [91 rows x 5 columns]

# %%
ts = df.loc[:, ['Close']]
ts.index = df['Date']
ts
# Out:
#                  Close
# Date
# 2016-01-29   24.607237
# 2016-02-29   23.936625
# 2016-03-31   26.066818
# 2016-04-29   26.684762
# 2016-05-31   23.743690
# ...                ...
# 2023-03-31  154.964782
# 2023-04-28  165.045790
# 2023-05-31  172.622728
# 2023-06-30  184.283333
# 2023-07-31  190.495001
#
# [91 rows x 1 columns]

# %%
# fig = plt.figure(figsize=(16, 6))
# axes1 = fig.add_subplot(211)
# fig = sm.graphics.tsa.plot_acf(ts, lags=50, ax=axes1)

# %%
# ARIMA 모델만들기
model = ARIMA(df_apple_total['Close'].values, order=(0,1,2))
model_fit = model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   91
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                -297.308
# Date:                Wed, 12 Jul 2023   AIC                            600.616
# Time:                        12:26:09   BIC                            608.116
# Sample:                             0   HQIC                           603.640
#                                  - 91
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.2553      0.090      2.824      0.005       0.078       0.433
# ma.L2         -0.0272      0.086     -0.315      0.753      -0.196       0.142
# sigma2        43.3001      4.975      8.703      0.000      33.549      53.052
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                10.19
# Prob(Q):                              0.63   Prob(JB):                         0.01
# Heteroskedasticity (H):              25.28   Skew:                            -0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
fig = model_fit.plot_diagnostics()

# %%
# 다음번에 예측결과 보도
model_fit.forecast()
# Out:
# array([191.1273937])

# %%
df_predict = pd.DataFrame(model_fit.predict())
df_predict.columns = ['predict']
df_predict
# Out:
#        predict
# 0     0.000000
# 1    24.607501
# 2    23.780262
# 3    26.661763
# 4    26.628897
# ..         ...
# 86  154.782750
# 87  154.604534
# 88  167.706958
# 89  173.593786
# 90  186.879073
#
# [91 rows x 1 columns]
